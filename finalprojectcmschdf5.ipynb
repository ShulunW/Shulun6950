# %%
import pandas as pd
from pandas import HDFStore
import numpy as np
import h5py

df5 = pd.read_csv ("winequality-white.csv")
df5.to_hdf('file_data.h5', key='df', mode='w')
df5 = pd.DataFrame(np.array(h5py.File('file_data.h5')['df']))
print(df5)
# Out:
#                0
# 0          axis0
# 1          axis1
# 2   block0_items
# 3  block0_values
# 4   block1_items
# 5  block1_values

# %%
import pandas as pd
from pandas import HDFStore
df = pd.read_csv ("winequality-white.csv")#Read csv file into df

dfwine=pd.DataFrame(df)#display as dataframe

dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
dfwine.describe()#Basice statistics of the dataframe
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
## allow matplotlib to embed plots in the notebook:
# %matplotlib inline
import matplotlib.pyplot as plt

ax = dfwine['quality'].value_counts().plot(kind='bar',title="Frequency for each quality level")
plt.xlabel('Quality level')
plt.ylabel('Frequency')
plt.show()

from scipy import stats
stats.describe(dfwine['quality'])
# Out:
# DescribeResult(nobs=4898, minmax=(3, 9), mean=5.87790935075541, variance=0.7843556854710506, skewness=0.15574868141362455, kurtosis=0.21508011570192975)

# %%
'''
plt.plot(dfwine["density"],dfwine["residual sugar"],"o")
plt.title('density Vs residual sugar')
plt.xlabel('density')
plt.ylabel('residual sugar')
plt.show()

plt.plot(dfwine["pH"],dfwine["fixed acidity"],"o")
plt.title('pH Vs fixed acidity')
plt.xlabel('pH')
plt.ylabel('fixed acidity')
plt.show()

plt.plot(dfwine["total sulfur dioxide"],dfwine["free sulfur dioxide"],"o")
plt.title('total.sulfur.dioxide Vs free.sulfur.dioxide')
plt.xlabel('total sulfur dioxide')
plt.ylabel('free sulfur dioxide')
plt.show()

plt.plot(dfwine["density"],dfwine["alcohol"],"o")
plt.title('Quality Vs alcohol')
plt.xlabel('density')
plt.ylabel('alcohol')
plt.show()



class draw_pics:
    def __init__(self,array1,array2,title1):
        self.array1=array1
        self.array2=array2
        self.title1=title1
 
    def draw(self):
        plt.plot(dfwine[self.array1],dfwine[self.array2],"o")
        plt.title(self.title1)
        plt.xlabel(self.array1)
        plt.ylabel(self.array2)
        plt.show()
'''
import classes
from classes import draw_pics
        
Pic1 = draw_pics("density","residual sugar",'density Vs residual sugar')
Pic1.draw()

Pic2 = draw_pics("pH","fixed acidity",'pH Vs fixed acidity')
Pic2.draw()

Pic3 = draw_pics("total sulfur dioxide","free sulfur dioxide",'total.sulfur.dioxide Vs free.sulfur.dioxide')
Pic3.draw()

Pic4 = draw_pics("density","alcohol",'Density Vs alcohol')
Pic4.draw()

# %%
import statsmodels.api as sm
from sklearn import linear_model

#Making preparation for runing linear regression
'''
#Explanatory variables
X = dfwine.iloc[:,0:11]

#Response variable
y = dfwine['quality']

#Adding intercept to the model
X = sm.add_constant(X)

#Building regression model
fit_linear = sm.OLS(y,X).fit()
print(fit_linear.summary())

class tabels:
    def __init__(self,index1,y_name):
        self.index1=index1
        self.y_name=y_name
    
    def draw_tab(self):
        X = dfwine.drop(columns=[self.index1])
        y = dfwine[self.y_name]
        X = sm.add_constant(X)
        fit_linear = sm.OLS(y,X).fit()
        print(fit_linear.summary())
'''
from classes import tabels
tab1=tabels('quality','quality')
tab1.draw_tab()
fit_linear = tab1.get_linear()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     174.3
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):               0.00
# Time:                        18:11:48   Log-Likelihood:                -5543.7
# No. Observations:                4898   AIC:                         1.111e+04
# Df Residuals:                    4886   BIC:                         1.119e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  150.1928     18.804      7.987      0.000     113.328     187.057
# ...

# %%
#The formula for Cook’s distance is:

#Di = (ri2 / p*MSE) * (hii / (1-hii)2)


import numpy as np
np.set_printoptions(suppress=True)

#create instance of influence
influence = fit_linear.get_influence()

#obtain Cook's distance for each observation
cooks = influence.cooks_distance

#display Cook's distances value
print(cooks)

#Plotting cooks distance
'''
plt.figure(figsize=(10, 7))
plt.plot(list(range(0,4898)), cooks[0],"o")
plt.xlim([0, 5000])
plt.xlabel('Wine ID')
plt.ylabel('Cooks Distance value')
plt.show()

class cook_dis:
    def __init__(self,range0,range1,range2,range3,range4,x_label2,y_label2):
        self.range0=range0
        self.range1=range1
        self.range2=range2
        self.range3=range3
        self.range4=range4
        self.x_label2=x_label2
        self.y_label2=y_label2
        
    def scatter(self):
        plt.figure(figsize=(self.range0,self.range1))
        plt.plot(self.range2, self.range3,"o")
        plt.xlim(self.range4)
        plt.xlabel(self.x_label2)
        plt.ylabel(self.y_label2)
        plt.show()
 '''
from classes import cook_dis
distance1 = cook_dis(10, 7,list(range(0,4898)),cooks[0],[0, 5000],'Wine ID','Cooks Distance value')
distance1.scatter()
# Out:
# (array([0.00005942, 0.00014247, 0.00001534, ..., 0.00013838, 0.00004946,
#        0.00003006]), array([1., 1., 1., ..., 1., 1., 1.]))

# %%
#Removing outliers observation

dfcooks = pd.DataFrame(cooks[0],list(range(0,4898)))
# getting a series object containing 
# maxmun value from each column
# of given dataframe
print(dfcooks)
print(dfcooks.nlargest(2,0))#Display 2 largest of column 0
#Observation2781 and 4745
# Out:
#              0
# 0     0.000059
# 1     0.000142
# 2     0.000015
# 3     0.000006
# 4     0.000006
# ...        ...
# 4893  0.000003
# 4894  0.000053
# 4895  0.000138
# 4896  0.000049
# 4897  0.000030
#
# [4898 rows x 1 columns]
#             0
# 2781  1.04050
# 4745  0.13129

# %%
#We proceed to delete these two observation from the dataframe
dfwinecooks1=dfwine.drop(labels=[2781,4745], axis=0)
dfwinecooks1
#Now we have left with 4896 observations
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Explanatory variables
X_1 = dfwinecooks1.iloc[:,0:11]

#Response variable
y_1 = dfwinecooks1['quality']

#Adding intercept to the model
X_1 = sm.add_constant(X_1)

fit_linearcooks1 = sm.OLS(y_1,X_1).fit()
print(fit_linearcooks1.summary())

np.set_printoptions(suppress=True)

#create instance of influence
influence_1 = fit_linearcooks1.get_influence()

#obtain Cook's distance for each observation
cooks_1 = influence_1.cooks_distance

#Plotting cooks distance
'''
plt.figure(figsize=(10, 7))
plt.plot(list(range(0,4896)), cooks_1[0],"o")
plt.xlim([0, 5000])
plt.xlabel('Wine ID')
plt.ylabel('Cooks Distance value')
plt.show()
'''
distance2 = cook_dis(10, 7,list(range(0,4896)),cooks_1[0],[0, 5000],'Wine ID','Cooks Distance value')
distance2.scatter()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     179.4
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):               0.00
# Time:                        18:11:49   Log-Likelihood:                -5517.0
# No. Observations:                4896   AIC:                         1.106e+04
# Df Residuals:                    4884   BIC:                         1.114e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  210.7214     22.674      9.294      0.000     166.271     255.172
# ...

# %%
dfcooks_1 = pd.DataFrame(cooks_1[0],list(range(0,4896)))
# getting a series object containing 
# maxmun value from each column
# of given dataframe
print(dfcooks_1)
print(dfcooks_1.nlargest(2,0))
#Observation 3307 and 1931
# Out:
#              0
# 0     0.000079
# 1     0.000161
# 2     0.000013
# 3     0.000005
# 4     0.000005
# ...        ...
# 4891  0.000003
# 4892  0.000066
# 4893  0.000136
# 4894  0.000051
# 4895  0.000035
#
# [4896 rows x 1 columns]
#              0
# 3306  0.022675
# 1931  0.019104

# %%
#We proceed to delete these two observation from the dataframe
dfwinefinal=dfwinecooks1.drop(labels=[3307,1931], axis=0)
dfwinefinal
#Now we have left with 4894 observations
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Check the cooks distance plot again

X_2 = dfwinefinal.iloc[:,0:11]

#Response variable
y_2 = dfwinefinal['quality']

#Adding intercept to the model
X_2 = sm.add_constant(X_2)

fit_linearcooks2 = sm.OLS(y_2,X_2).fit()
#print(fit_linearcooks2.summary())

np.set_printoptions(suppress=True)

#create instance of influence
influence_2 = fit_linearcooks2.get_influence()

#obtain Cook's distance for each observation
cooks_2 = influence_2.cooks_distance


#Plotting cooks distance
'''
plt.figure(figsize=(10, 7))
plt.plot(list(range(0,4894)), cooks_2[0],"o")
plt.xlim([0, 5000])
plt.xlabel('Wine ID')
plt.ylabel('Cooks Distance value')
plt.show()
'''
distance2 = cook_dis(10, 7,list(range(0,4894)),cooks_2[0],[0, 5000],'Wine ID','Cooks Distance value')
distance2.scatter()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

#the independent variables set with a column of constant 1. 
#Since it is required for running regression.

#The entire explantory variables with a constant column
X_vif = pd.DataFrame(add_constant(dfwinefinal.iloc[:,0:11]))

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i)
                          for i in range(len(X_vif.columns))]
  
print(vif_data)


#Extra variables are removed based on the VIF criterion, here the removed variables are 
#residual.sugar, density,total sulfur dioxide and alcohol. 
#The adjusted data set has much better VIF information.

cols = [0,1,2,3,5,6,9,10]
X_vif_1= pd.DataFrame(add_constant(X_vif[X_vif.columns[cols]]))

# VIF dataframe
vif_data_1 = pd.DataFrame()
vif_data_1["feature adjusted"] = X_vif_1.columns
  
# calculating VIF for each feature
vif_data_1["VIF"] = [variance_inflation_factor(X_vif_1.values, i)
                          for i in range(len(X_vif_1.columns))]
  
print(vif_data_1)
# Out:
#                  feature           VIF
# 0                  const  4.504402e+06
# 1          fixed acidity  3.252740e+00
# 2       volatile acidity  1.131962e+00
# 3            citric acid  1.165448e+00
# 4         residual sugar  1.611569e+01
# 5              chlorides  1.241587e+00
# 6    free sulfur dioxide  1.779965e+00
# 7   total sulfur dioxide  2.275136e+00
# 8                density  3.948711e+01
# 9                     pH  2.484938e+00
# 10             sulphates  1.162071e+00
# 11               alcohol  1.096247e+01
#       feature adjusted         VIF
# 0                const  854.600289
# 1        fixed acidity    1.313383
# 2     volatile acidity    1.044719
# 3          citric acid    1.152561
# 4            chlorides    1.038785
# 5  free sulfur dioxide    1.039288
# 6                   pH    1.272667
# 7            sulphates    1.037933

# %%
#Now we have the final dataset ready for building a logistic regression.
cols_1 = [0,1,2,3,5,6,9,10,11]
wwfinal=pd.DataFrame(add_constant(dfwinefinal[dfwinefinal.columns[cols_1]]))
wwfinal.head(10)

wwfinal['level'] = np.where(wwfinal['quality'] > 5, 'Fine', 'Poor') 

wwfinal.head(20)

wwfinal.to_hdf('whitewineFinal.h5', key='df', mode='w') #Saving the processed data into hd5 file.

# %%
#Spliting dataset into training and testing
#from sklearn.model_selection import train_test_split

#X_t=wwfinal.iloc[:,0:8]

#wwtrain, wwtest = train_test_split(wwfinal, test_size=0.2,random_state=424)

#This method does not include the corresponding y values, we found a better function
#for performing this task.

# %%
from sklearn.model_selection import train_test_split
#Ignoring quality variable
X_lo = wwfinal.iloc[:,0:8]

#Treat the responde variable as categorical variable
y_lo = wwfinal['level'].astype('category')

#Spliting the final dataframe in to testing and training with its corresponding x and y 
X_train,X_test,y_train,y_test = train_test_split(X_lo,y_lo,test_size=0.2,random_state=92815)

# %%
from sklearn.linear_model import LogisticRegression


fit_lo= LogisticRegression(solver='lbfgs', max_iter=1000)
#A model is now built using 80% of the final dataset, which we called training set
fit_lo.fit(X_train,y_train)

#Our predicted category based on the logistics model using the training dataset.
y_pred=fit_lo.predict(X_test)

#Now we have the predicted value using the training model, an also the actual value
#we ignored from the testing set, now the goal is to build a condusion matrix.

# %%
#Building a Confusion Matrix

import seaborn as sn
from sklearn import metrics
'''
cm = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(cm, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()

class metrics_:
    def __init__(self,y_test, y_pred,rowname,colname):
        self.y_test=y_test
        self.y_pred=y_pred
        self.rowname=rowname
        self.colname=colname

    def produce(self):
        cm = pd.crosstab(self.y_test, self.y_pred, rownames=[self.rowname], colnames=[self.colname])
        sn.heatmap(cm, annot=True)
        print('Accuracy: ',metrics.accuracy_score(self.y_test, self.y_pred))
        plt.show()
'''
from classes import metrics_
metrics1=metrics_(y_test, y_pred,'Actual','Predicted')
metrics1.produce()
# Out:
# Accuracy:  0.7017364657814096
